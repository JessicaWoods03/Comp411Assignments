# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaWoods03/Comp411Assignments/blob/main/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
CSV_ROWS = [0,1,2,3,4,5,6,78,9,10]

# %% [markdown]
# This is the data I am using to put in a CSV file.

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv"
)
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv"
)
train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

# %% [markdown]
# This shows you the size of the data which is 120 rows and 5 columns...this prints out what the panda's can read.
# So you can see the data I am using for this homework- The datatype is ints, species are numbered as
# Setosa = 0
# Versacolor = 1
# Virginica = 2

# %%
print(train)
print(test)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0            6.4         2.8          5.6         2.2        2
# 1            5.0         2.3          3.3         1.0        1
# 2            4.9         2.5          4.5         1.7        2
# 3            4.9         3.1          1.5         0.1        0
# 4            5.7         3.8          1.7         0.3        0
# ..           ...         ...          ...         ...      ...
# 115          5.5         2.6          4.4         1.2        1
# 116          5.7         3.0          4.2         1.2        1
# 117          4.4         2.9          1.4         0.2        0
# 118          4.8         3.0          1.4         0.1        0
# 119          5.5         2.4          3.7         1.0        1
#
# [120 rows x 5 columns]
#     SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0           5.9         3.0          4.2         1.5        1
# 1           6.9         3.1          5.4         2.1        2
# ...

# %% [markdown]
# This pulls it by the row listing the species 0,1,2-

# %%
print (train.loc[1])
# Out:
# SepalLength    5.0
# SepalWidth     2.3
# PetalLength    3.3
# PetalWidth     1.0
# Species        1.0
# Name: 1, dtype: float64

# %%
print (train.loc[2])
# Out:
# SepalLength    4.9
# SepalWidth     2.5
# PetalLength    4.5
# PetalWidth     1.7
# Species        2.0
# Name: 2, dtype: float64

# %% [markdown]
# This is a basic plot below of the data-

# %%
train.pop('Species')
train.plot()

# %% [markdown]
# This is a analysis of the data below-
# Describe() gives a summary of each numerical attribute in the dataframe of train which i popped Species off of-

# %%
train.head()

# %%
train.tail()

# %%
train.describe()

# %% [markdown]
# Describing Series and Dataframes:
# A Series- is a one-dimensional object that can hold any data type such as integers, floats and strings.
# A DataFrame- is a two dimensional object that can have columns with potential different types. Different kind of inputs include dictionaries, lists, series, and even another DataFrame. Examples are below:

# %%
x = pd.Series([6,3,4,6]) 
print(x)
dates = pd.date_range("20200605", periods = 5)
print(dates)
